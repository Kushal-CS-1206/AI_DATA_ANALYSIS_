# %% [markdown]
# ### Integrating with Apache Airflow
# **Description**: Integrate Great Expectations with Apache Airflow to run data quality checks automatically in your DAG.
#
# **Steps**:
# 1. Install Airflow (if you haven't already):
# 2. Airflow DAG Integration:
#     - Create a DAG file:
# 3. Deploy and Test:
#     - Place this file in your Airflow DAGs directory and start your Airflow scheduler.
#     - Open the Airflow UI and trigger the DAG to see it run your expectations.

# %%
# Write your code from here
# !pip install "apache-airflow==2.7.2" --constraint "https://raw.githubusercontent.com/apache/airflow/constraints-2.7.2/constraints-3.8.txt"
# !pip install great_expectations
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting apache-airflow==2.7.2
#   Downloading apache_airflow-2.7.2-py3-none-any.whl (12.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 26.6 MB/s eta 0:00:0000:0100:01
# Collecting gunicorn>=20.1.0
#   Downloading gunicorn-21.2.0-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.2/80.2 kB 18.1 MB/s eta 0:00:00
# Collecting sqlalchemy-jsonfield>=1.0
#   Downloading SQLAlchemy_JSONField-1.0.1.post0-py3-none-any.whl (10 kB)
# Collecting croniter>=0.3.17
#   Downloading croniter-1.4.1-py2.py3-none-any.whl (19 kB)
# Collecting connexion[flask]>=2.10.0
#   Downloading connexion-2.14.2-py2.py3-none-any.whl (95 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.1/95.1 kB 20.0 MB/s eta 0:00:00
# Collecting cron-descriptor>=1.2.24
#   Downloading cron_descriptor-1.4.0.tar.gz (29 kB)
#   Preparing metadata (setup.py) ... done
# Collecting rich-argparse>=1.0.0
#   Downloading rich_argparse-1.3.0-py3-none-any.whl (17 kB)
# Collecting flask-login>=0.6.2
#   Downloading Flask_Login-0.6.2-py3-none-any.whl (17 kB)
# Collecting setproctitle>=1.1.8
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Collecting dill>=0.2.2
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.0/152.0 kB 27.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting unicodecsv>=0.14.1
#   Downloading unicodecsv-0.14.1.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting marshmallow-oneofschema>=2.0.1
#   Downloading marshmallow_oneofschema-3.0.1-py2.py3-none-any.whl (5.8 kB)
# Collecting markdown>=3.0
#   Downloading Markdown-3.5-py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 20.2 MB/s eta 0:00:00
# Collecting argcomplete>=1.10
#   Downloading argcomplete-3.1.2-py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.5/41.5 kB 9.6 MB/s eta 0:00:00
# Collecting apache-airflow-providers-common-sql
#   Downloading apache_airflow_providers_common_sql-1.7.2-py3-none-any.whl (31 kB)
# Collecting deprecated>=1.2.13
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting asgiref
#   Downloading asgiref-3.7.2-py3-none-any.whl (24 kB)
# Collecting markupsafe>=1.1.1
#   Downloading MarkupSafe-2.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Requirement already satisfied: rfc3339-validator>=0.1.4 in /home/vscode/.local/lib/python3.10/site-packages (from apache-airflow==2.7.2) (0.1.4)
# Collecting colorlog<5.0,>=4.0.2
#   Downloading colorlog-4.8.0-py2.py3-none-any.whl (10 kB)
# Collecting python-slugify>=5.0
#   Downloading python_slugify-8.0.1-py2.py3-none-any.whl (9.7 kB)
# Collecting httpx
#   Downloading httpx-0.23.3-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 15.0 MB/s eta 0:00:00
# Collecting cattrs>=22.1.0
#   Downloading cattrs-23.1.2-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 12.2 MB/s eta 0:00:00
# Collecting google-re2>=1.0
#   Downloading google_re2-1.1-6-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (516 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 516.5/516.5 kB 36.8 MB/s eta 0:00:00
# Collecting pathspec>=0.9.0
#   Downloading pathspec-0.11.2-py3-none-any.whl (29 kB)
# Collecting tabulate>=0.7.5
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting jsonschema>=4.18.0
#   Downloading jsonschema-4.19.1-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.3/83.3 kB 18.2 MB/s eta 0:00:00
# Collecting lockfile>=0.12.2
#   Downloading lockfile-0.12.2-py2.py3-none-any.whl (13 kB)
# Collecting tenacity!=8.2.0,>=6.2.0
#   Downloading tenacity-8.2.3-py3-none-any.whl (24 kB)
# Collecting flask-session>=0.4.0
#   Downloading flask_session-0.5.0-py3-none-any.whl (7.2 kB)
# Collecting apache-airflow-providers-http
#   Downloading apache_airflow_providers_http-4.5.2-py3-none-any.whl (24 kB)
# Collecting typing-extensions>=4.0.0
#   Downloading typing_extensions-4.8.0-py3-none-any.whl (31 kB)
# Collecting opentelemetry-api>=1.15.0
#   Downloading opentelemetry_api-1.20.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 14.8 MB/s eta 0:00:00
# Collecting flask-wtf>=0.15
#   Downloading flask_wtf-1.2.1-py3-none-any.whl (12 kB)
# Collecting itsdangerous>=2.0
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Collecting python-nvd3>=0.15.0
#   Downloading python-nvd3-0.15.0.tar.gz (31 kB)
#   Preparing metadata (setup.py) ... done
# Collecting jinja2>=3.0.0
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.1/133.1 kB 18.6 MB/s eta 0:00:00
# Collecting mdit-py-plugins>=0.3.0
#   Downloading mdit_py_plugins-0.4.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.1/54.1 kB 11.5 MB/s eta 0:00:00
# Collecting lazy-object-proxy
#   Downloading lazy_object_proxy-1.9.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 kB 14.9 MB/s eta 0:00:00
# Collecting opentelemetry-exporter-otlp
#   Downloading opentelemetry_exporter_otlp-1.20.0-py3-none-any.whl (7.0 kB)
# Requirement already satisfied: markdown-it-py>=2.1.0 in /home/vscode/.local/lib/python3.10/site-packages (from apache-airflow==2.7.2) (3.0.0)
# Collecting pendulum>=2.0
#   Downloading pendulum-2.1.2.tar.gz (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.2/81.2 kB 17.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting alembic<2.0,>=1.6.3
#   Downloading alembic-1.12.0-py3-none-any.whl (226 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.0/226.0 kB 31.5 MB/s eta 0:00:00
# Collecting flask<2.3,>=2.2
#   Downloading Flask-2.2.5-py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 kB 19.9 MB/s eta 0:00:00
# Collecting pluggy>=1.0
#   Downloading pluggy-1.3.0-py3-none-any.whl (18 kB)
# Collecting python-dateutil>=2.3
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 kB 27.8 MB/s eta 0:00:00
# Collecting pyjwt>=2.0.0
#   Downloading PyJWT-2.8.0-py3-none-any.whl (22 kB)
# Collecting apache-airflow-providers-sqlite
#   Downloading apache_airflow_providers_sqlite-3.4.3-py3-none-any.whl (13 kB)
# Collecting cryptography>=0.9.3
#   Downloading cryptography-41.0.4-cp37-abi3-manylinux_2_28_x86_64.whl (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 33.3 MB/s eta 0:00:0000:01m
# Collecting blinker
#   Downloading blinker-1.6.3-py3-none-any.whl (13 kB)
# Collecting configupdater>=3.1.1
#   Downloading ConfigUpdater-3.1.1-py2.py3-none-any.whl (34 kB)
# Collecting psutil>=4.2.0
#   Downloading psutil-5.9.5-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (282 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 282.1/282.1 kB 36.1 MB/s eta 0:00:00
# Collecting sqlalchemy<2.0,>=1.4.28
#   Downloading SQLAlchemy-1.4.49-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 41.6 MB/s eta 0:00:00:00:01
# Collecting flask-appbuilder==4.3.6
#   Downloading Flask_AppBuilder-4.3.6-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 45.3 MB/s eta 0:00:00:00:01
# Collecting python-daemon>=3.0.0
#   Downloading python_daemon-3.0.1-py3-none-any.whl (31 kB)
# Collecting packaging>=14.0
#   Downloading packaging-23.2-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 11.3 MB/s eta 0:00:00
# Collecting termcolor>=1.1.0
#   Downloading termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Collecting linkify-it-py>=2.0.0
#   Downloading linkify_it_py-2.0.2-py3-none-any.whl (19 kB)
# Collecting rich>=12.4.4
#   Downloading rich-13.6.0-py3-none-any.whl (239 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.8/239.8 kB 30.7 MB/s eta 0:00:00
# Collecting apache-airflow-providers-imap
#   Downloading apache_airflow_providers_imap-3.3.2-py3-none-any.whl (17 kB)
# Collecting pydantic>=1.10.0
#   Downloading pydantic-2.4.2-py3-none-any.whl (395 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.8/395.8 kB 35.9 MB/s eta 0:00:00
# Collecting flask-caching>=1.5.0
#   Downloading Flask_Caching-2.0.2-py3-none-any.whl (28 kB)
# Collecting graphviz>=0.12
#   Downloading graphviz-0.20.1-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.0/47.0 kB 9.6 MB/s eta 0:00:00
# Collecting pygments>=2.0.1
#   Downloading Pygments-2.16.1-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 40.4 MB/s eta 0:00:00
# Collecting werkzeug>=2.0
#   Downloading Werkzeug-2.2.3-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 33.2 MB/s eta 0:00:00
# Collecting apache-airflow-providers-ftp
#   Downloading apache_airflow_providers_ftp-3.5.2-py3-none-any.whl (18 kB)
# Collecting attrs>=22.1.0
#   Downloading attrs-23.1.0-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 13.2 MB/s eta 0:00:00
# Collecting click<9,>=8
#   Downloading click-8.1.7-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 18.0 MB/s eta 0:00:00
# Collecting marshmallow-sqlalchemy<0.27.0,>=0.22.0
#   Downloading marshmallow_sqlalchemy-0.26.1-py2.py3-none-any.whl (15 kB)
# Collecting WTForms<4
#   Downloading WTForms-3.0.1-py3-none-any.whl (136 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.5/136.5 kB 27.0 MB/s eta 0:00:00
# Collecting apispec[yaml]<7,>=6.0.0
#   Downloading apispec-6.3.0-py3-none-any.whl (29 kB)
# Collecting prison<1.0.0,>=0.2.1
#   Downloading prison-0.2.1-py2.py3-none-any.whl (5.8 kB)
# Collecting Flask-JWT-Extended<5.0.0,>=4.0.0
#   Downloading Flask_JWT_Extended-4.5.3-py2.py3-none-any.whl (22 kB)
# Collecting marshmallow<4,>=3.18.0
#   Downloading marshmallow-3.20.1-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 8.7 MB/s eta 0:00:00
# Collecting Flask-SQLAlchemy<3,>=2.4
#   Downloading Flask_SQLAlchemy-2.5.1-py2.py3-none-any.whl (17 kB)
# Requirement already satisfied: colorama<1,>=0.3.9 in /home/vscode/.local/lib/python3.10/site-packages (from flask-appbuilder==4.3.6->apache-airflow==2.7.2) (0.4.6)
# Collecting Flask-Limiter<4,>3
#   Downloading Flask_Limiter-3.5.0-py3-none-any.whl (28 kB)
# Collecting Flask-Babel<3,>=1
#   Downloading Flask_Babel-2.0.0-py3-none-any.whl (9.3 kB)
# Collecting email-validator<2,>=1.0.5
#   Downloading email_validator-1.3.1-py2.py3-none-any.whl (22 kB)
# Collecting sqlalchemy-utils<1,>=0.32.21
#   Downloading SQLAlchemy_Utils-0.41.1-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 kB 18.3 MB/s eta 0:00:00
# Collecting Mako
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 14.0 MB/s eta 0:00:00
# Collecting exceptiongroup
#   Downloading exceptiongroup-1.1.3-py3-none-any.whl (14 kB)
# Collecting clickclick<21,>=1.2
#   Downloading clickclick-20.10.2-py2.py3-none-any.whl (7.4 kB)
# Collecting inflection<0.6,>=0.3.1
#   Downloading inflection-0.5.1-py2.py3-none-any.whl (9.5 kB)
# Collecting requests<3,>=2.9.1
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 13.6 MB/s eta 0:00:00
# Collecting PyYAML<7,>=5.1
#   Downloading PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (705 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.5/705.5 kB 30.3 MB/s eta 0:00:00
# Collecting cffi>=1.12
#   Downloading cffi-1.16.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (443 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 443.9/443.9 kB 6.7 MB/s eta 0:00:0000:01
# Collecting wrapt<2,>=1.10
#   Downloading wrapt-1.15.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 15.8 MB/s eta 0:00:00
# Collecting cachelib<0.10.0,>=0.9.0
#   Downloading cachelib-0.9.0-py3-none-any.whl (15 kB)
# Collecting referencing>=0.28.4
#   Downloading referencing-0.30.2-py3-none-any.whl (25 kB)
# Collecting jsonschema-specifications>=2023.03.6
#   Downloading jsonschema_specifications-2023.7.1-py3-none-any.whl (17 kB)
# Collecting rpds-py>=0.7.1
#   Downloading rpds_py-0.10.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 47.7 MB/s eta 0:00:00
# Collecting uc-micro-py
#   Downloading uc_micro_py-1.0.2-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: mdurl~=0.1 in /home/vscode/.local/lib/python3.10/site-packages (from markdown-it-py>=2.1.0->apache-airflow==2.7.2) (0.1.2)
# Collecting importlib-metadata<7.0,>=6.0
#   Downloading importlib_metadata-6.8.0-py3-none-any.whl (22 kB)
# Collecting pytzdata>=2020.1
#   Downloading pytzdata-2020.1-py2.py3-none-any.whl (489 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 490.0/490.0 kB 39.8 MB/s eta 0:00:00
# Collecting pydantic-core==2.10.1
#   Downloading pydantic_core-2.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 47.6 MB/s eta 0:00:00:00:01
# Collecting annotated-types>=0.4.0
#   Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: setuptools>=62.4.0 in /usr/local/lib/python3.10/site-packages (from python-daemon>=3.0.0->apache-airflow==2.7.2) (67.8.0)
# Collecting docutils
#   Downloading docutils-0.20.1-py3-none-any.whl (572 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.7/572.7 kB 43.9 MB/s eta 0:00:00
# Collecting six>=1.5
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting text-unidecode>=1.3
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.2/78.2 kB 17.7 MB/s eta 0:00:00
# Collecting greenlet!=0.4.17
#   Downloading greenlet-3.0.0-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (612 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.9/612.9 kB 41.7 MB/s eta 0:00:00
# Collecting sqlparse>=0.4.2
#   Downloading sqlparse-0.4.4-py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 8.4 MB/s eta 0:00:00
# Collecting aiohttp
#   Downloading aiohttp-3.8.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 13.7 MB/s eta 0:00:0000:0100:01
# Collecting requests-toolbelt
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 12.7 MB/s eta 0:00:00
# Collecting httpcore<0.17.0,>=0.15.0
#   Downloading httpcore-0.16.3-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 kB 13.9 MB/s eta 0:00:00
# Collecting certifi
#   Downloading certifi-2023.7.22-py3-none-any.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 27.5 MB/s eta 0:00:00
# Collecting rfc3986[idna2008]<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting sniffio
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting opentelemetry-exporter-otlp-proto-http==1.20.0
#   Downloading opentelemetry_exporter_otlp_proto_http-1.20.0-py3-none-any.whl (16 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc==1.20.0
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.20.0-py3-none-any.whl (18 kB)
# Collecting opentelemetry-sdk~=1.20.0
#   Downloading opentelemetry_sdk-1.20.0-py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.9/103.9 kB 21.1 MB/s eta 0:00:00
# Collecting opentelemetry-proto==1.20.0
#   Downloading opentelemetry_proto-1.20.0-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 11.3 MB/s eta 0:00:00
# Collecting googleapis-common-protos~=1.52
#   Downloading googleapis_common_protos-1.60.0-py2.py3-none-any.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.6/227.6 kB 29.0 MB/s eta 0:00:00
# Collecting opentelemetry-exporter-otlp-proto-common==1.20.0
#   Downloading opentelemetry_exporter_otlp_proto_common-1.20.0-py3-none-any.whl (17 kB)
# Collecting backoff<3.0.0,>=1.10.0
#   Downloading backoff-1.10.0-py2.py3-none-any.whl (31 kB)
# Collecting grpcio<2.0.0,>=1.0.0
#   Downloading grpcio-1.59.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 27.1 MB/s eta 0:00:0000:0100:01m
# Collecting protobuf<5.0,>=3.19
#   Downloading protobuf-4.21.12-cp37-abi3-manylinux2014_x86_64.whl (409 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.8/409.8 kB 40.0 MB/s eta 0:00:00
# Collecting pycparser
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.7/118.7 kB 22.8 MB/s eta 0:00:00
# Collecting idna>=2.0.0
#   Downloading idna-3.4-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 13.3 MB/s eta 0:00:00
# Collecting dnspython>=1.15.0
#   Downloading dnspython-2.4.2-py3-none-any.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 38.0 MB/s eta 0:00:00
# Collecting Babel>=2.3
#   Downloading Babel-2.13.0-py3-none-any.whl (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 37.6 MB/s eta 0:00:0000:010:01m
# Collecting pytz
#   Downloading pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.5/502.5 kB 35.3 MB/s eta 0:00:00
# Collecting ordered-set<5,>4
#   Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Collecting limits>=2.8
#   Downloading limits-3.6.0-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.0/43.0 kB 9.8 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 12.8 MB/s eta 0:00:00
# Collecting anyio<5.0,>=3.0
#   Downloading anyio-4.0.0-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 17.5 MB/s eta 0:00:00
# Collecting zipp>=0.5
#   Downloading zipp-3.17.0-py3-none-any.whl (7.4 kB)
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 26.1 MB/s eta 0:00:00
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-1.26.17-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.4/143.4 kB 21.8 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.4.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (225 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.7/225.7 kB 28.9 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 34.1 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 22.2 MB/s eta 0:00:00
# Collecting importlib-resources>=1.3
#   Downloading importlib_resources-6.1.0-py3-none-any.whl (33 kB)
# Collecting opentelemetry-semantic-conventions==0.41b0
#   Downloading opentelemetry_semantic_conventions-0.41b0-py3-none-any.whl (26 kB)
# Building wheels for collected packages: cron-descriptor, dill, pendulum, python-nvd3, unicodecsv
#   Building wheel for cron-descriptor (setup.py) ... done
#   Created wheel for cron-descriptor: filename=cron_descriptor-1.4.0-py3-none-any.whl size=49837 sha256=b25ddf643b121c423fa6f099e4fd3fe34f2aa5a24317622372ef17af9859ee4c
#   Stored in directory: /home/vscode/.cache/pip/wheels/98/ff/fb/d908f229155ad6b65c7a34e9d35774fd1f40579241c3a5f924
#   Building wheel for dill (setup.py) ... done
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78545 sha256=255ab6b4ac0d7ff6b59f5391ec4178b411eb312b409e739f8dc4f946fb08f889
#   Stored in directory: /home/vscode/.cache/pip/wheels/ea/e2/86/64980d90e297e7bf2ce588c2b96e818f5399c515c4bb8a7e4f
#   Building wheel for pendulum (pyproject.toml) ... done
#   Created wheel for pendulum: filename=pendulum-2.1.2-cp310-cp310-manylinux_2_31_x86_64.whl size=159139 sha256=58c60eea3eb160f83a2ae1a58ce74d409135d1b6f7c0db6d1d224512d2baa3db
#   Stored in directory: /home/vscode/.cache/pip/wheels/2e/41/ed/f113e4c9dc10f6c846d69f412e9cd9aa429960a3e2e485a4f9
#   Building wheel for python-nvd3 (setup.py) ... done
#   Created wheel for python-nvd3: filename=python_nvd3-0.15.0-py3-none-any.whl size=38149 sha256=503f5b619cc6c481c147ead70638700a0fe918c351034fcc38e5ddeb30e67cf5
#   Stored in directory: /home/vscode/.cache/pip/wheels/80/e7/4e/d99e473adde7dd21b9938d4d32bf823ca334e7979632d6a64c
#   Building wheel for unicodecsv (setup.py) ... done
#   Created wheel for unicodecsv: filename=unicodecsv-0.14.1-py3-none-any.whl size=10745 sha256=691bb4c6ec44863d16fb9d33deca2050745016494db4592cd1e43afe49fe85a4
#   Stored in directory: /home/vscode/.cache/pip/wheels/9c/ea/66/8e45247b09052a933eb1a680b7c64802298faba58aac9b346b
# Successfully built cron-descriptor dill pendulum python-nvd3 unicodecsv
# Installing collected packages: unicodecsv, text-unidecode, rfc3986, pytz, lockfile, cron-descriptor, colorlog, zipp, wrapt, urllib3, uc-micro-py, typing-extensions, termcolor, tenacity, tabulate, sqlparse, sniffio, six, setproctitle, rpds-py, PyYAML, pytzdata, python-slugify, pyjwt, pygments, pycparser, psutil, protobuf, pluggy, pathspec, packaging, ordered-set, opentelemetry-semantic-conventions, multidict, markupsafe, markdown, lazy-object-proxy, itsdangerous, inflection, importlib-resources, idna, h11, grpcio, greenlet, graphviz, google-re2, frozenlist, exceptiongroup, docutils, dnspython, dill, configupdater, click, charset-normalizer, certifi, cachelib, blinker, backoff, Babel, attrs, async-timeout, argcomplete, annotated-types, yarl, WTForms, werkzeug, sqlalchemy, rich, requests, referencing, python-dateutil, python-daemon, pydantic-core, prison, opentelemetry-proto, mdit-py-plugins, marshmallow, Mako, linkify-it-py, jinja2, importlib-metadata, gunicorn, googleapis-common-protos, email-validator, deprecated, clickclick, cffi, cattrs, asgiref, apispec, anyio, aiosignal, sqlalchemy-utils, sqlalchemy-jsonfield, rich-argparse, requests-toolbelt, python-nvd3, pydantic, pendulum, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, marshmallow-sqlalchemy, marshmallow-oneofschema, limits, jsonschema-specifications, httpcore, flask, cryptography, croniter, alembic, aiohttp, opentelemetry-sdk, jsonschema, httpx, flask-wtf, Flask-SQLAlchemy, flask-session, flask-login, Flask-Limiter, Flask-JWT-Extended, flask-caching, Flask-Babel, opentelemetry-exporter-otlp-proto-http, opentelemetry-exporter-otlp-proto-grpc, flask-appbuilder, connexion, opentelemetry-exporter-otlp, apache-airflow-providers-common-sql, apache-airflow-providers-sqlite, apache-airflow-providers-imap, apache-airflow-providers-http, apache-airflow-providers-ftp, apache-airflow
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2025.2
#     Uninstalling pytz-2025.2:
#       Successfully uninstalled pytz-2025.2
#   Attempting uninstall: zipp
#     Found existing installation: zipp 3.21.0
#     Uninstalling zipp-3.21.0:
#       Successfully uninstalled zipp-3.21.0
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.17.2
#     Uninstalling wrapt-1.17.2:
#       Successfully uninstalled wrapt-1.17.2
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.4.0
#     Uninstalling urllib3-2.4.0:
#       Successfully uninstalled urllib3-2.4.0
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.13.2
#     Uninstalling typing_extensions-4.13.2:
#       Successfully uninstalled typing_extensions-4.13.2
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 3.1.0
#     Uninstalling termcolor-3.1.0:
#       Successfully uninstalled termcolor-3.1.0
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.1.2
#     Uninstalling tenacity-9.1.2:
#       Successfully uninstalled tenacity-9.1.2
#   Attempting uninstall: sniffio
#     Found existing installation: sniffio 1.3.1
#     Uninstalling sniffio-1.3.1:
#       Successfully uninstalled sniffio-1.3.1
#   Attempting uninstall: six
#     Found existing installation: six 1.17.0
#     Uninstalling six-1.17.0:
#       Successfully uninstalled six-1.17.0
#   Attempting uninstall: rpds-py
#     Found existing installation: rpds-py 0.25.0
#     Uninstalling rpds-py-0.25.0:
#       Successfully uninstalled rpds-py-0.25.0
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 6.0.2
#     Uninstalling PyYAML-6.0.2:
#       Successfully uninstalled PyYAML-6.0.2
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.19.1
#     Uninstalling Pygments-2.19.1:
#       Successfully uninstalled Pygments-2.19.1
#   Attempting uninstall: pycparser
#     Found existing installation: pycparser 2.22
#     Uninstalling pycparser-2.22:
#       Successfully uninstalled pycparser-2.22
#   Attempting uninstall: psutil
#     Found existing installation: psutil 7.0.0
#     Uninstalling psutil-7.0.0:
#       Successfully uninstalled psutil-7.0.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.4
#     Uninstalling protobuf-5.29.4:
#       Successfully uninstalled protobuf-5.29.4
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.2
#     Uninstalling packaging-24.2:
#       Successfully uninstalled packaging-24.2
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
#   Attempting uninstall: markdown
#     Found existing installation: Markdown 3.8
#     Uninstalling Markdown-3.8:
#       Successfully uninstalled Markdown-3.8
#   Attempting uninstall: itsdangerous
#     Found existing installation: itsdangerous 2.2.0
#     Uninstalling itsdangerous-2.2.0:
#       Successfully uninstalled itsdangerous-2.2.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
#   Attempting uninstall: h11
#     Found existing installation: h11 0.16.0
#     Uninstalling h11-0.16.0:
#       Successfully uninstalled h11-0.16.0
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.71.0
#     Uninstalling grpcio-1.71.0:
#       Successfully uninstalled grpcio-1.71.0
#   Attempting uninstall: exceptiongroup
#     Found existing installation: exceptiongroup 1.2.2
#     Uninstalling exceptiongroup-1.2.2:
#       Successfully uninstalled exceptiongroup-1.2.2
#   Attempting uninstall: click
#     Found existing installation: click 8.2.0
#     Uninstalling click-8.2.0:
#       Successfully uninstalled click-8.2.0
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 3.4.2
#     Uninstalling charset-normalizer-3.4.2:
#       Successfully uninstalled charset-normalizer-3.4.2
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2025.4.26
#     Uninstalling certifi-2025.4.26:
#       Successfully uninstalled certifi-2025.4.26
#   Attempting uninstall: blinker
#     Found existing installation: blinker 1.9.0
#     Uninstalling blinker-1.9.0:
#       Successfully uninstalled blinker-1.9.0
#   Attempting uninstall: backoff
#     Found existing installation: backoff 2.2.1
#     Uninstalling backoff-2.2.1:
#       Successfully uninstalled backoff-2.2.1
#   Attempting uninstall: Babel
#     Found existing installation: babel 2.17.0
#     Uninstalling babel-2.17.0:
#       Successfully uninstalled babel-2.17.0
#   Attempting uninstall: attrs
#     Found existing installation: attrs 25.3.0
#     Uninstalling attrs-25.3.0:
#       Successfully uninstalled attrs-25.3.0
#   Attempting uninstall: annotated-types
#     Found existing installation: annotated-types 0.7.0
#     Uninstalling annotated-types-0.7.0:
#       Successfully uninstalled annotated-types-0.7.0
#   Attempting uninstall: werkzeug
#     Found existing installation: Werkzeug 3.0.6
#     Uninstalling Werkzeug-3.0.6:
#       Successfully uninstalled Werkzeug-3.0.6
#   Attempting uninstall: rich
#     Found existing installation: rich 14.0.0
#     Uninstalling rich-14.0.0:
#       Successfully uninstalled rich-14.0.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
#   Attempting uninstall: referencing
#     Found existing installation: referencing 0.36.2
#     Uninstalling referencing-0.36.2:
#       Successfully uninstalled referencing-0.36.2
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.9.0.post0
#     Uninstalling python-dateutil-2.9.0.post0:
#       Successfully uninstalled python-dateutil-2.9.0.post0
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.33.2
#     Uninstalling pydantic_core-2.33.2:
#       Successfully uninstalled pydantic_core-2.33.2
#   Attempting uninstall: marshmallow
#     Found existing installation: marshmallow 3.26.1
#     Uninstalling marshmallow-3.26.1:
#       Successfully uninstalled marshmallow-3.26.1
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 3.1.6
#     Uninstalling Jinja2-3.1.6:
#       Successfully uninstalled Jinja2-3.1.6
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 8.7.0
#     Uninstalling importlib_metadata-8.7.0:
#       Successfully uninstalled importlib_metadata-8.7.0
#   Attempting uninstall: cffi
#     Found existing installation: cffi 1.17.1
#     Uninstalling cffi-1.17.1:
#       Successfully uninstalled cffi-1.17.1
#   Attempting uninstall: anyio
#     Found existing installation: anyio 4.9.0
#     Uninstalling anyio-4.9.0:
#       Successfully uninstalled anyio-4.9.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.22
#     Uninstalling pydantic-1.10.22:
#       Successfully uninstalled pydantic-1.10.22
#   Attempting uninstall: jsonschema-specifications
#     Found existing installation: jsonschema-specifications 2025.4.1
#     Uninstalling jsonschema-specifications-2025.4.1:
#       Successfully uninstalled jsonschema-specifications-2025.4.1
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 1.0.9
#     Uninstalling httpcore-1.0.9:
#       Successfully uninstalled httpcore-1.0.9
#   Attempting uninstall: flask
#     Found existing installation: Flask 3.0.3
#     Uninstalling Flask-3.0.3:
#       Successfully uninstalled Flask-3.0.3
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 45.0.2
#     Uninstalling cryptography-45.0.2:
#       Successfully uninstalled cryptography-45.0.2
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.23.0
#     Uninstalling jsonschema-4.23.0:
#       Successfully uninstalled jsonschema-4.23.0
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.28.1
#     Uninstalling httpx-0.28.1:
#       Successfully uninstalled httpx-0.28.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydata-profiling 4.16.1 requires matplotlib<=3.10,>=3.5, but you have matplotlib 3.10.3 which is incompatible.
# visions 0.8.1 requires pandas>=2.0.0, but you have pandas 1.5.3 which is incompatible.
# typing-inspection 0.4.0 requires typing-extensions>=4.12.0, but you have typing-extensions 4.8.0 which is incompatible.
# typeguard 4.4.2 requires typing_extensions>=4.10.0, but you have typing-extensions 4.8.0 which is incompatible.
# jupyterlab 4.4.2 requires httpx>=0.25.0, but you have httpx 0.23.3 which is incompatible.
# great-expectations 0.16.15 requires pydantic<2.0,>=1.9.2, but you have pydantic 2.4.2 which is incompatible.
# Successfully installed Babel-2.13.0 Flask-Babel-2.0.0 Flask-JWT-Extended-4.5.3 Flask-Limiter-3.5.0 Flask-SQLAlchemy-2.5.1 Mako-1.2.4 PyYAML-6.0.1 WTForms-3.0.1 aiohttp-3.8.6 aiosignal-1.3.1 alembic-1.12.0 annotated-types-0.6.0 anyio-4.0.0 apache-airflow-2.7.2 apache-airflow-providers-common-sql-1.7.2 apache-airflow-providers-ftp-3.5.2 apache-airflow-providers-http-4.5.2 apache-airflow-providers-imap-3.3.2 apache-airflow-providers-sqlite-3.4.3 apispec-6.3.0 argcomplete-3.1.2 asgiref-3.7.2 async-timeout-4.0.3 attrs-23.1.0 backoff-1.10.0 blinker-1.6.3 cachelib-0.9.0 cattrs-23.1.2 certifi-2023.7.22 cffi-1.16.0 charset-normalizer-3.3.0 click-8.1.7 clickclick-20.10.2 colorlog-4.8.0 configupdater-3.1.1 connexion-2.14.2 cron-descriptor-1.4.0 croniter-1.4.1 cryptography-41.0.4 deprecated-1.2.14 dill-0.3.1.1 dnspython-2.4.2 docutils-0.20.1 email-validator-1.3.1 exceptiongroup-1.1.3 flask-2.2.5 flask-appbuilder-4.3.6 flask-caching-2.0.2 flask-login-0.6.2 flask-session-0.5.0 flask-wtf-1.2.1 frozenlist-1.4.0 google-re2-1.1 googleapis-common-protos-1.60.0 graphviz-0.20.1 greenlet-3.0.0 grpcio-1.59.0 gunicorn-21.2.0 h11-0.14.0 httpcore-0.16.3 httpx-0.23.3 idna-3.4 importlib-metadata-6.8.0 importlib-resources-6.1.0 inflection-0.5.1 itsdangerous-2.1.2 jinja2-3.1.2 jsonschema-4.19.1 jsonschema-specifications-2023.7.1 lazy-object-proxy-1.9.0 limits-3.6.0 linkify-it-py-2.0.2 lockfile-0.12.2 markdown-3.5 markupsafe-2.1.3 marshmallow-3.20.1 marshmallow-oneofschema-3.0.1 marshmallow-sqlalchemy-0.26.1 mdit-py-plugins-0.4.0 multidict-6.0.4 opentelemetry-api-1.20.0 opentelemetry-exporter-otlp-1.20.0 opentelemetry-exporter-otlp-proto-common-1.20.0 opentelemetry-exporter-otlp-proto-grpc-1.20.0 opentelemetry-exporter-otlp-proto-http-1.20.0 opentelemetry-proto-1.20.0 opentelemetry-sdk-1.20.0 opentelemetry-semantic-conventions-0.41b0 ordered-set-4.1.0 packaging-23.2 pathspec-0.11.2 pendulum-2.1.2 pluggy-1.3.0 prison-0.2.1 protobuf-4.21.12 psutil-5.9.5 pycparser-2.21 pydantic-2.4.2 pydantic-core-2.10.1 pygments-2.16.1 pyjwt-2.8.0 python-daemon-3.0.1 python-dateutil-2.8.2 python-nvd3-0.15.0 python-slugify-8.0.1 pytz-2023.3.post1 pytzdata-2020.1 referencing-0.30.2 requests-2.31.0 requests-toolbelt-1.0.0 rfc3986-1.5.0 rich-13.6.0 rich-argparse-1.3.0 rpds-py-0.10.4 setproctitle-1.3.3 six-1.16.0 sniffio-1.3.0 sqlalchemy-1.4.49 sqlalchemy-jsonfield-1.0.1.post0 sqlalchemy-utils-0.41.1 sqlparse-0.4.4 tabulate-0.9.0 tenacity-8.2.3 termcolor-2.3.0 text-unidecode-1.3 typing-extensions-4.8.0 uc-micro-py-1.0.2 unicodecsv-0.14.1 urllib3-1.26.17 werkzeug-2.2.3 wrapt-1.15.0 yarl-1.9.2 zipp-3.17.0
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: great_expectations in /home/vscode/.local/lib/python3.10/site-packages (0.16.15)
# Collecting pydantic<2.0,>=1.9.2
#   Using cached pydantic-1.10.22-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
# Requirement already satisfied: jsonschema>=2.5.1 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (4.19.1)
# Requirement already satisfied: pandas<2.0.0,>=1.3.0 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (1.5.3)
# Requirement already satisfied: ipywidgets>=7.5.1 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (8.1.7)
# Requirement already satisfied: requests>=2.20 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (2.31.0)
# Requirement already satisfied: Ipython>=7.16.3 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (8.36.0)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (4.8.0)
# Requirement already satisfied: Click>=7.1.2 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (8.1.7)
# Requirement already satisfied: urllib3>=1.26 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (1.26.17)
# Requirement already satisfied: colorama>=0.4.3 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (0.4.6)
# Requirement already satisfied: jinja2>=2.10 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (3.1.2)
# Requirement already satisfied: numpy>=1.23.0 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (1.26.4)
# Requirement already satisfied: nbformat>=5.0 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (5.10.4)
# Requirement already satisfied: packaging in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (23.2)
# Requirement already satisfied: mistune>=0.8.4 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (3.1.3)
# Requirement already satisfied: tqdm>=4.59.0 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (2.8.2)
# Requirement already satisfied: tzlocal>=1.2 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (5.3.1)
# Requirement already satisfied: importlib-metadata>=1.7.0 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (6.8.0)
# Requirement already satisfied: jsonpatch>=1.22 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (1.33)
# Requirement already satisfied: pytz>=2021.3 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (2023.3.post1)
# Requirement already satisfied: makefun<2,>=1.7.0 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (1.16.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.7.1 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (3.20.1)
# Requirement already satisfied: notebook>=6.4.10 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (7.4.2)
# Requirement already satisfied: pyparsing>=2.4 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (3.2.3)
# Requirement already satisfied: altair<5.0.0,>=4.2.1 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (4.2.2)
# Requirement already satisfied: cryptography>=3.2 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (41.0.4)
# Requirement already satisfied: ruamel.yaml<0.17.18,>=0.16 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (0.17.17)
# Requirement already satisfied: scipy>=1.6.0 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (1.10.1)
# Requirement already satisfied: entrypoints in /home/vscode/.local/lib/python3.10/site-packages (from altair<5.0.0,>=4.2.1->great_expectations) (0.4)
# Requirement already satisfied: toolz in /home/vscode/.local/lib/python3.10/site-packages (from altair<5.0.0,>=4.2.1->great_expectations) (1.0.0)
# Requirement already satisfied: cffi>=1.12 in /home/vscode/.local/lib/python3.10/site-packages (from cryptography>=3.2->great_expectations) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in /home/vscode/.local/lib/python3.10/site-packages (from importlib-metadata>=1.7.0->great_expectations) (3.17.0)
# Requirement already satisfied: decorator in /home/vscode/.local/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations) (5.2.1)
# Requirement already satisfied: traitlets>=5.13.0 in /home/vscode/.local/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations) (5.14.3)
# Requirement already satisfied: stack_data in /home/vscode/.local/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations) (0.6.3)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/vscode/.local/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations) (3.0.51)
# Requirement already satisfied: pexpect>4.3 in /home/vscode/.local/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations) (4.9.0)
# Requirement already satisfied: pygments>=2.4.0 in /home/vscode/.local/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations) (2.16.1)
# Requirement already satisfied: matplotlib-inline in /home/vscode/.local/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations) (0.1.7)
# Requirement already satisfied: exceptiongroup in /home/vscode/.local/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations) (1.1.3)
# Requirement already satisfied: jedi>=0.16 in /home/vscode/.local/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations) (0.19.2)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/vscode/.local/lib/python3.10/site-packages (from ipywidgets>=7.5.1->great_expectations) (3.0.15)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/vscode/.local/lib/python3.10/site-packages (from ipywidgets>=7.5.1->great_expectations) (4.0.14)
# Requirement already satisfied: comm>=0.1.3 in /home/vscode/.local/lib/python3.10/site-packages (from ipywidgets>=7.5.1->great_expectations) (0.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/vscode/.local/lib/python3.10/site-packages (from jinja2>=2.10->great_expectations) (2.1.3)
# Requirement already satisfied: jsonpointer>=1.9 in /home/vscode/.local/lib/python3.10/site-packages (from jsonpatch>=1.22->great_expectations) (3.0.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/vscode/.local/lib/python3.10/site-packages (from jsonschema>=2.5.1->great_expectations) (23.1.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/vscode/.local/lib/python3.10/site-packages (from jsonschema>=2.5.1->great_expectations) (0.10.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/vscode/.local/lib/python3.10/site-packages (from jsonschema>=2.5.1->great_expectations) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/vscode/.local/lib/python3.10/site-packages (from jsonschema>=2.5.1->great_expectations) (0.30.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/vscode/.local/lib/python3.10/site-packages (from nbformat>=5.0->great_expectations) (5.7.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/vscode/.local/lib/python3.10/site-packages (from nbformat>=5.0->great_expectations) (2.21.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/vscode/.local/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations) (2.16.0)
# Requirement already satisfied: jupyterlab<4.5,>=4.4.0 in /home/vscode/.local/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations) (4.4.2)
# Requirement already satisfied: tornado>=6.2.0 in /home/vscode/.local/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations) (6.4.2)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /home/vscode/.local/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations) (0.2.4)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /home/vscode/.local/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations) (2.27.3)
# Requirement already satisfied: six>=1.5 in /home/vscode/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.1->great_expectations) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/vscode/.local/lib/python3.10/site-packages (from requests>=2.20->great_expectations) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/vscode/.local/lib/python3.10/site-packages (from requests>=2.20->great_expectations) (3.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vscode/.local/lib/python3.10/site-packages (from requests>=2.20->great_expectations) (2023.7.22)
# Requirement already satisfied: pycparser in /home/vscode/.local/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=3.2->great_expectations) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/vscode/.local/lib/python3.10/site-packages (from jedi>=0.16->Ipython>=7.16.3->great_expectations) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=5.0->great_expectations) (4.3.8)
# Requirement already satisfied: terminado>=0.8.3 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (1.8.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (23.1.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (0.5.3)
# Requirement already satisfied: anyio>=3.1.0 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (4.0.0)
# Requirement already satisfied: pyzmq>=24 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (26.4.0)
# Requirement already satisfied: nbconvert>=6.4.4 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (7.16.6)
# Requirement already satisfied: send2trash>=1.8.2 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (1.8.3)
# Requirement already satisfied: prometheus-client>=0.9 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (0.22.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (8.6.3)
# Requirement already satisfied: overrides>=5.0 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (7.7.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (0.12.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/vscode/.local/lib/python3.10/site-packages (from jupyterlab<4.5,>=4.4.0->notebook>=6.4.10->great_expectations) (2.2.5)
# Requirement already satisfied: ipykernel>=6.5.0 in /home/vscode/.local/lib/python3.10/site-packages (from jupyterlab<4.5,>=4.4.0->notebook>=6.4.10->great_expectations) (6.29.5)
# Requirement already satisfied: setuptools>=41.1.0 in /usr/local/lib/python3.10/site-packages (from jupyterlab<4.5,>=4.4.0->notebook>=6.4.10->great_expectations) (67.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /home/vscode/.local/lib/python3.10/site-packages (from jupyterlab<4.5,>=4.4.0->notebook>=6.4.10->great_expectations) (2.0.5)
# Requirement already satisfied: tomli>=1.2.2 in /home/vscode/.local/lib/python3.10/site-packages (from jupyterlab<4.5,>=4.4.0->notebook>=6.4.10->great_expectations) (2.2.1)
# Collecting httpx>=0.25.0
#   Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Requirement already satisfied: babel>=2.10 in /home/vscode/.local/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.4.10->great_expectations) (2.13.0)
# Requirement already satisfied: json5>=0.9.0 in /home/vscode/.local/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.4.10->great_expectations) (0.12.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/vscode/.local/lib/python3.10/site-packages (from pexpect>4.3->Ipython>=7.16.3->great_expectations) (0.7.0)
# Requirement already satisfied: wcwidth in /home/vscode/.local/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->Ipython>=7.16.3->great_expectations) (0.2.13)
# Requirement already satisfied: asttokens>=2.1.0 in /home/vscode/.local/lib/python3.10/site-packages (from stack_data->Ipython>=7.16.3->great_expectations) (3.0.0)
# Requirement already satisfied: pure-eval in /home/vscode/.local/lib/python3.10/site-packages (from stack_data->Ipython>=7.16.3->great_expectations) (0.2.3)
# Requirement already satisfied: executing>=1.2.0 in /home/vscode/.local/lib/python3.10/site-packages (from stack_data->Ipython>=7.16.3->great_expectations) (2.2.0)
# Requirement already satisfied: sniffio>=1.1 in /home/vscode/.local/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/vscode/.local/lib/python3.10/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (21.2.0)
# Collecting httpcore==1.*
#   Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Collecting h11>=0.16
#   Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: debugpy>=1.6.5 in /home/vscode/.local/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.0->notebook>=6.4.10->great_expectations) (1.8.14)
# Requirement already satisfied: psutil in /home/vscode/.local/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.0->notebook>=6.4.10->great_expectations) (5.9.5)
# Requirement already satisfied: nest-asyncio in /home/vscode/.local/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.0->notebook>=6.4.10->great_expectations) (1.6.0)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (0.1.1)
# Requirement already satisfied: rfc3339-validator in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (0.1.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (3.3.0)
# Requirement already satisfied: pyyaml>=5.3 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (6.0.1)
# Requirement already satisfied: jupyterlab-pygments in /home/vscode/.local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (0.3.0)
# Requirement already satisfied: beautifulsoup4 in /home/vscode/.local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (4.13.4)
# Requirement already satisfied: defusedxml in /home/vscode/.local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (0.7.1)
# Requirement already satisfied: nbclient>=0.5.0 in /home/vscode/.local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/vscode/.local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (1.5.1)
# Requirement already satisfied: bleach[css]!=5.0.0 in /home/vscode/.local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (6.2.0)
# Requirement already satisfied: webencodings in /home/vscode/.local/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /home/vscode/.local/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (1.4.0)
# Requirement already satisfied: webcolors>=1.11 in /home/vscode/.local/lib/python3.10/site-packages (from jsonschema>=2.5.1->great_expectations) (24.11.1)
# Requirement already satisfied: fqdn in /home/vscode/.local/lib/python3.10/site-packages (from jsonschema>=2.5.1->great_expectations) (1.5.1)
# Requirement already satisfied: uri-template in /home/vscode/.local/lib/python3.10/site-packages (from jsonschema>=2.5.1->great_expectations) (1.3.0)
# Requirement already satisfied: isoduration in /home/vscode/.local/lib/python3.10/site-packages (from jsonschema>=2.5.1->great_expectations) (20.11.0)
# Requirement already satisfied: soupsieve>1.2 in /home/vscode/.local/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (2.7)
# Requirement already satisfied: arrow>=0.15.0 in /home/vscode/.local/lib/python3.10/site-packages (from isoduration->jsonschema>=2.5.1->great_expectations) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /home/vscode/.local/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema>=2.5.1->great_expectations) (2.9.0.20250516)
# Installing collected packages: pydantic, h11, httpcore, httpx
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.4.2
#     Uninstalling pydantic-2.4.2:
#       Successfully uninstalled pydantic-2.4.2
#   Attempting uninstall: h11
#     Found existing installation: h11 0.14.0
#     Uninstalling h11-0.14.0:
#       Successfully uninstalled h11-0.14.0
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 0.16.3
#     Uninstalling httpcore-0.16.3:
#       Successfully uninstalled httpcore-0.16.3
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.23.3
#     Uninstalling httpx-0.23.3:
#       Successfully uninstalled httpx-0.23.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydata-profiling 4.16.1 requires matplotlib<=3.10,>=3.5, but you have matplotlib 3.10.3 which is incompatible.
# ydata-profiling 4.16.1 requires pydantic>=2, but you have pydantic 1.10.22 which is incompatible.
# Successfully installed h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 pydantic-1.10.22
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
from datetime import datetime
from airflow import DAG
from airflow.operators.python import PythonOperator
import great_expectations as gx
import pandas as pd

def validate_data():
    df = pd.DataFrame({
        "customer_id": [1, 2, 3],
        "purchase_amount": [120.5, 89.0, 300.75],
        "age": [25, 40, 60]
    })

    context = gx.get_context()

    suite = context.add_or_update_expectation_suite("customer_suite")

    validator = context.sources.pandas_default.read_dataframe(df)
    validator.expect_column_to_exist("customer_id")
    validator.expect_column_values_to_be_of_type("purchase_amount", "FLOAT")
    validator.expect_column_values_to_be_between("age", min_value=18, max_value=65)

    validator.save_expectation_suite(discard_failed_expectations=False)

    checkpoint = context.add_or_update_checkpoint(
        name="customer_checkpoint",
        validator=validator,
    )

    result = checkpoint.run()
    assert result["success"], "Data validation failed!"

with DAG(
    dag_id="gx_airflow_validation",
    start_date=datetime(2024, 1, 1),
    schedule_interval="@daily",
    catchup=False,
) as dag:
    task = PythonOperator(
        task_id="run_validation",
        python_callable=validate_data
    )
# Out:
# [2025-05-20T15:47:16.973+0000] {warnings.py:109} WARNING - /tmp/ipykernel_52191/3636649549.py:33: RemovedInAirflow3Warning: Param `schedule_interval` is deprecated and will be removed in a future release. Please use `schedule` instead.
#   with DAG(
