# %% [markdown]
# ### Basic ML Model Monitoring with MLFlow
# **Description**: Set up a basic ML model monitoring pipeline using MLFlow to track experiment parameters and results.
#
# **Steps**:
# 1. Installation
# 2. Set Up MLFlow Tracking
# 3. Training a Simple Model
# 4. Logging Model and Metrics
# 5. View Logged Data
#     - Access the MLFlow UI to view your logged parameters, metrics, and models.

# %%
# !pip install mlflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting mlflow
#   Downloading mlflow-2.22.0-py3-none-any.whl (29.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.0/29.0 MB 16.7 MB/s eta 0:00:0000:0100:01
# Collecting mlflow-skinny==2.22.0
#   Downloading mlflow_skinny-2.22.0-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 34.4 MB/s eta 0:00:0000:0100:01m
# Requirement already satisfied: Flask<4 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow) (2.2.5)
# Requirement already satisfied: scikit-learn<2 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow) (1.6.1)
# Requirement already satisfied: markdown<4,>=3.3 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow) (3.5)
# Collecting docker<8,>=4.0.0
#   Downloading docker-7.1.0-py3-none-any.whl (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 26.3 MB/s eta 0:00:00
# Requirement already satisfied: Jinja2<4,>=2.11 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow) (3.1.2)
# Requirement already satisfied: pandas<3 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow) (1.5.3)
# Collecting pyarrow<20,>=4.0.0
#   Downloading pyarrow-19.0.1-cp310-cp310-manylinux_2_28_x86_64.whl (42.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 MB 10.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy<3 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow) (1.26.4)
# Requirement already satisfied: scipy<2 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow) (1.10.1)
# Requirement already satisfied: alembic!=1.10.0,<2 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow) (1.12.0)
# Collecting graphene<4
#   Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 21.6 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib<4 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow) (3.10.3)
# Requirement already satisfied: gunicorn<24 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow) (21.2.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow) (1.4.49)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow) (3.1.44)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow) (1.20.0)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow) (0.4.4)
# Requirement already satisfied: click<9,>=7.0 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow) (8.1.7)
# Collecting uvicorn<1
#   Downloading uvicorn-0.34.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow) (1.20.0)
# Requirement already satisfied: requests<3,>=2.17.3 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow) (2.31.0)
# Collecting databricks-sdk<1,>=0.20.0
#   Downloading databricks_sdk-0.53.0-py3-none-any.whl (700 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 700.2/700.2 kB 39.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging<25 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow) (23.2)
# Requirement already satisfied: pydantic<3,>=1.10.8 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow) (1.10.22)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow) (6.8.0)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow) (5.5.2)
# Collecting cloudpickle<4
#   Downloading cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow) (4.21.12)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow) (4.8.0)
# Requirement already satisfied: pyyaml<7,>=5.1 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow) (6.0.1)
# Collecting fastapi<1
#   Downloading fastapi-0.115.12-py3-none-any.whl (95 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 20.0 MB/s eta 0:00:00
# Requirement already satisfied: Mako in /home/vscode/.local/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow) (1.2.4)
# Requirement already satisfied: urllib3>=1.26.0 in /home/vscode/.local/lib/python3.10/site-packages (from docker<8,>=4.0.0->mlflow) (1.26.17)
# Requirement already satisfied: itsdangerous>=2.0 in /home/vscode/.local/lib/python3.10/site-packages (from Flask<4->mlflow) (2.1.2)
# Requirement already satisfied: Werkzeug>=2.2.2 in /home/vscode/.local/lib/python3.10/site-packages (from Flask<4->mlflow) (2.2.3)
# Collecting graphql-core<3.3,>=3.1
#   Downloading graphql_core-3.2.6-py3-none-any.whl (203 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.4/203.4 kB 31.9 MB/s eta 0:00:00
# Collecting graphql-relay<3.3,>=3.1
#   Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /home/vscode/.local/lib/python3.10/site-packages (from graphene<4->mlflow) (2.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/vscode/.local/lib/python3.10/site-packages (from Jinja2<4,>=2.11->mlflow) (2.1.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/vscode/.local/lib/python3.10/site-packages (from matplotlib<4->mlflow) (3.2.3)
# Requirement already satisfied: pillow>=8 in /home/vscode/.local/lib/python3.10/site-packages (from matplotlib<4->mlflow) (11.2.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/vscode/.local/lib/python3.10/site-packages (from matplotlib<4->mlflow) (1.4.8)
# Requirement already satisfied: cycler>=0.10 in /home/vscode/.local/lib/python3.10/site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/vscode/.local/lib/python3.10/site-packages (from matplotlib<4->mlflow) (4.57.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/vscode/.local/lib/python3.10/site-packages (from matplotlib<4->mlflow) (1.3.2)
# Requirement already satisfied: pytz>=2020.1 in /home/vscode/.local/lib/python3.10/site-packages (from pandas<3->mlflow) (2023.3.post1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/vscode/.local/lib/python3.10/site-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/vscode/.local/lib/python3.10/site-packages (from scikit-learn<2->mlflow) (1.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /home/vscode/.local/lib/python3.10/site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.0.0)
# Collecting google-auth~=2.0
#   Downloading google_auth-2.40.1-py2.py3-none-any.whl (216 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.1/216.1 kB 32.4 MB/s eta 0:00:00
# Collecting starlette<0.47.0,>=0.40.0
#   Downloading starlette-0.46.2-py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 15.9 MB/s eta 0:00:00
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/vscode/.local/lib/python3.10/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.22.0->mlflow) (4.0.12)
# Requirement already satisfied: zipp>=0.5 in /home/vscode/.local/lib/python3.10/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.22.0->mlflow) (3.17.0)
# Requirement already satisfied: deprecated>=1.2.6 in /home/vscode/.local/lib/python3.10/site-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow) (1.2.14)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.41b0 in /home/vscode/.local/lib/python3.10/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow) (0.41b0)
# Requirement already satisfied: six>=1.5 in /home/vscode/.local/lib/python3.10/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/vscode/.local/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.22.0->mlflow) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/vscode/.local/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.22.0->mlflow) (3.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vscode/.local/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.22.0->mlflow) (2023.7.22)
# Requirement already satisfied: h11>=0.8 in /home/vscode/.local/lib/python3.10/site-packages (from uvicorn<1->mlflow-skinny==2.22.0->mlflow) (0.16.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/vscode/.local/lib/python3.10/site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow) (1.15.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/vscode/.local/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.22.0->mlflow) (5.0.2)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 25.8 MB/s eta 0:00:00
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Requirement already satisfied: anyio<5,>=3.6.2 in /home/vscode/.local/lib/python3.10/site-packages (from starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==2.22.0->mlflow) (4.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/vscode/.local/lib/python3.10/site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==2.22.0->mlflow) (1.1.3)
# Requirement already satisfied: sniffio>=1.1 in /home/vscode/.local/lib/python3.10/site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==2.22.0->mlflow) (1.3.0)
# Collecting pyasn1<0.7.0,>=0.6.1
#   Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 18.2 MB/s eta 0:00:00
# Installing collected packages: uvicorn, pyasn1, pyarrow, graphql-core, cloudpickle, starlette, rsa, pyasn1-modules, graphql-relay, docker, graphene, google-auth, fastapi, databricks-sdk, mlflow-skinny, mlflow
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 20.0.0
#     Uninstalling pyarrow-20.0.0:
#       Successfully uninstalled pyarrow-20.0.0
# Successfully installed cloudpickle-3.1.1 databricks-sdk-0.53.0 docker-7.1.0 fastapi-0.115.12 google-auth-2.40.1 graphene-3.4.3 graphql-core-3.2.6 graphql-relay-3.2.0 mlflow-2.22.0 mlflow-skinny-2.22.0 pyarrow-19.0.1 pyasn1-0.6.1 pyasn1-modules-0.4.2 rsa-4.9.1 starlette-0.46.2 uvicorn-0.34.2
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
import mlflow
import mlflow.sklearn
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

data = load_iris()
X_train, X_test, y_train, y_test = train_test_split(data.data, data.target, random_state=42)

with mlflow.start_run():
    model = RandomForestClassifier(n_estimators=100)
    model.fit(X_train, y_train)
    preds = model.predict(X_test)
    acc = accuracy_score(y_test, preds)
    mlflow.log_param("n_estimators", 100)
    mlflow.log_metric("accuracy", acc)
    mlflow.sklearn.log_model(model, "model")
# Out:
# 2025/05/20 16:50:32 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
