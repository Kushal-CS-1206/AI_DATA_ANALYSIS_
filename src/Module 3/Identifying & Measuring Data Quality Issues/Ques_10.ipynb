# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from io import StringIO

csv_data = """
ID,Age,Salary,Experience
1,28,50000,3
2,30,60000,5
3,23,55000,2
4,29,52000,4
5,31,58000,6
6,27,51000,3
7,26,54000,2
8,32,57000,7
9,25,53000,1
10,45,200000,20
"""

df = pd.read_csv(StringIO(csv_data))

# Data Profiling - Basic stats
print("Descriptive Statistics:")
print(df.describe())

# Outlier detection using boxplots
numeric_cols = df.select_dtypes(include=['number']).columns

for col in numeric_cols:
    plt.figure(figsize=(6, 3))
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot for {col}")
    plt.show()
# Out:
# Descriptive Statistics:
#              ID       Age         Salary  Experience
# count  10.00000  10.00000      10.000000   10.000000
# mean    5.50000  29.60000   69000.000000    5.300000
# std     3.02765   6.07728   46137.475729    5.498485
# min     1.00000  23.00000   50000.000000    1.000000
# 25%     3.25000  26.25000   52250.000000    2.250000
# 50%     5.50000  28.50000   54500.000000    3.500000
# 75%     7.75000  30.75000   57750.000000    5.750000
# max    10.00000  45.00000  200000.000000   20.000000
