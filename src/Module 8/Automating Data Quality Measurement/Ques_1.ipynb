# %% [markdown]
# ### Task 1: Basic Data Profiling of a CSV File
# **Description**: Load a CSV file and generate a Pandas-Profiling report.
#
# **Steps**:
# 1. Load a CSV File: Make sure you have a CSV file (e.g., data.csv ). Load it using pandas.
# 2. Generate a Profile Report.

# %%
import pandas as pd
from ydata_profiling import ProfileReport

# Sample CSV data as a string (simulate reading from a CSV file)
csv_data = """name,age,email,income
Alice,25,alice@example.com,50000
Bob,,bob@example.com,60000
Charlie,35,charlie@example.com,
David,40,david@example.com,80000
Eve,,eve@example.com,
"""

# Save CSV data to a file (simulate existing CSV file)
with open("data.csv", "w") as f:
    f.write(csv_data)

# Step 1: Load CSV file
df = pd.read_csv("data.csv")

# Step 2: Generate profile report with minimal=True to avoid dependency issues
profile = ProfileReport(df, title="Basic Data Profiling Report", minimal=True)

# Save the report to an HTML file
profile.to_file("data_profiling_report.html")

print("Data profiling report saved as 'data_profiling_report.html'")
# Out:
# 100%|██████████| 4/4 [00:00<00:00, 53601.33it/s]0:00, 120.01it/s, Describe variable: income]
# Summarize dataset: 100%|██████████| 10/10 [00:00<00:00, 263.44it/s, Completed]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 24
#      21 profile = ProfileReport(df, title="Basic Data Profiling Report", minimal=True)
#      23 # Save the report to an HTML file
# ---> 24 profile.to_file("data_profiling_report.html")
#      26 print("Data profiling report saved as 'data_profiling_report.html'")
#
# File ~/.local/lib/python3.10/site-packages/ydata_profiling/profile_report.py:381, in ProfileReport.to_file(self, output_file, silent)
#     378         self.config.html.assets_prefix = str(output_file.stem) + "_assets"
#     379     create_html_assets(self.config, output_file)
# --> 381 data = self.to_html()
#     383 if output_file.suffix != ".html":
#     384     suffix = output_file.suffix
#
# File ~/.local/lib/python3.10/site-packages/ydata_profiling/profile_report.py:498, in ProfileReport.to_html(self)
#     490 def to_html(self) -> str:
#     491     """Generate and return complete template as lengthy string
#     492         for using with frameworks.
#     493
#    (...)
#     496
#     497     """
# --> 498     return self.html
#
# File ~/.local/lib/python3.10/site-packages/ydata_profiling/profile_report.py:294, in ProfileReport.html(self)
#     291 @property
#     292 def html(self) -> str:
#     293     if self._html is None:
# --> 294         self._html = self._render_html()
#     295     return self._html
#
# File ~/.local/lib/python3.10/site-packages/ydata_profiling/profile_report.py:411, in ProfileReport._render_html(self)
#     408 def _render_html(self) -> str:
#     409     from ydata_profiling.report.presentation.flavours import HTMLReport
# --> 411     report = self.report
#     413     with tqdm(
#     414         total=1, desc="Render HTML", disable=not self.config.progress_bar
#     415     ) as pbar:
#     416         html = HTMLReport(copy.deepcopy(report)).render(
#     417             nav=self.config.html.navbar_show,
#     418             offline=self.config.html.use_local_assets,
#    (...)
#     426             version=self.description_set.package["ydata_profiling_version"],
#     427         )
#
# File ~/.local/lib/python3.10/site-packages/ydata_profiling/profile_report.py:288, in ProfileReport.report(self)
#     285 @property
#     286 def report(self) -> Root:
#     287     if self._report is None:
# --> 288         self._report = get_report_structure(self.config, self.description_set)
#     289     return self._report
#
# File ~/.local/lib/python3.10/site-packages/ydata_profiling/report/structure/report.py:388, in get_report_structure(config, summary)
#     368 section_items: List[Renderable] = [
#     369     Container(
#     370         get_dataset_items(config, summary, alerts),
#    (...)
#     375     ),
#     376 ]
#     378 if len(summary.variables) > 0:
#     379     section_items.append(
#     380         Dropdown(
#     381             name="Variables",
#     382             anchor_id="variables-dropdown",
#     383             id="variables-dropdown",
#     384             is_row=False,
#     385             classes=["form-select"],
#     386             items=list(summary.variables),
#     387             item=Container(
# --> 388                 render_variables_section(config, summary),
#     389                 sequence_type="accordion",
#     390                 name="Variables",
#     391                 anchor_id="variables",
#     392             ),
#     393         )
#     394     )
#     396 scatter_items = get_interactions(config, summary.scatter)
#     397 if len(scatter_items) > 0:
#
# File ~/.local/lib/python3.10/site-packages/ydata_profiling/report/structure/report.py:162, in render_variables_section(config, dataframe_summary)
#     160     variable_type = summary["type"]
#     161 render_map_type = render_map.get(variable_type, render_map["Unsupported"])
# --> 162 template_variables.update(render_map_type(config, template_variables))
#     164 # Ignore these
#     165 if reject_variables:
#
# File ~/.local/lib/python3.10/site-packages/ydata_profiling/report/structure/variables/render_text.py:81, in render_text(config, summary)
#      77 top_items.append(table)
#      79 if words and "word_counts" in summary:
#      80     mini_wordcloud = Image(
# ---> 81         plot_word_cloud(config, summary["word_counts"]),
#      82         image_format=config.plot.image_format,
#      83         alt="Mini wordcloud",
#      84     )
#      85     top_items.append(mini_wordcloud)
#      86 template_variables["top"] = Container(top_items, sequence_type="grid")
#
# File /usr/local/lib/python3.10/contextlib.py:78, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
# ---> 78     with self._recreate_cm():
#      79         return func(*args, **kwds)
#
# File /usr/local/lib/python3.10/contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File ~/.local/lib/python3.10/site-packages/ydata_profiling/visualisation/context.py:82, in manage_matplotlib_context()
#      80     yield
#      81 finally:
# ---> 82     deregister_matplotlib_converters()  # revert to original unit registries
#      83     with warnings.catch_warnings():
#      84         warnings.filterwarnings(
#      85             "ignore", category=matplotlib.MatplotlibDeprecationWarning
#      86         )
#
# File ~/.local/lib/python3.10/site-packages/pandas/plotting/_misc.py:151, in deregister()
#     112 def deregister() -> None:
#     113     """
#     114     Remove pandas formatters and converters.
#     115
#    (...)
#     149     TypeError: float() argument must be a string or a real number, not 'Period'
#     150     """
# --> 151     plot_backend = _get_plot_backend("matplotlib")
#     152     plot_backend.deregister()
#
# File ~/.local/lib/python3.10/site-packages/pandas/plotting/_core.py:1947, in _get_plot_backend(backend)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/.local/lib/python3.10/site-packages/pandas/plotting/_core.py:1877, in _load_backend(backend)
#    1872         module = importlib.import_module("pandas.plotting._matplotlib")
#    1873     except ImportError:
#    1874         raise ImportError(
#    1875             "matplotlib is required for plotting when the "
#    1876             'default backend "matplotlib" is selected.'
# -> 1877         ) from None
#    1878     return module
#    1880 found_backend = False
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.

# %% [markdown]
# ### Task 2: Understanding Missing Values with Pandas-Profiling
#
# **Description**: Identify missing values in your dataset using pandas-profiling.
#
# **Steps**:
# 1. Generate a Profile Report to Analyze Missing Values

# %%
# Write your code from here
import pandas as pd
from ydata_profiling import ProfileReport

# Sample dataset with missing values
data = {
    "name": ["Alice", "Bob", None, "David", "Eve"],
    "age": [25, None, 35, 40, None],
    "email": ["alice@example.com", None, "charlie@example.com", "david@example.com", "eve@example.com"],
    "income": [50000, 60000, None, 80000, None]
}

df = pd.DataFrame(data)

# Generate a profile report focused on missing values
profile = ProfileReport(df, title="Missing Values Analysis", explorative=True)

# Save report to an HTML file
profile.to_file("missing_values_report.html")

print("Missing values analysis report saved as 'missing_values_report.html'")
# Out:
#  25%|██▌       | 1/4 [00:00<00:00, 12.53it/s]0<00:00,  9.43it/s, Describe variable: income]
# Summarize dataset:  22%|██▏       | 2/9 [00:00<00:00, 12.39it/s, Describe variable: income]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_5262/3001212016.py in ?()
#      15 # Generate a profile report focused on missing values
#      16 profile = ProfileReport(df, title="Missing Values Analysis", explorative=True)
#      17
#      18 # Save report to an HTML file
# ---> 19 profile.to_file("missing_values_report.html")
#      20
#      21 print("Missing values analysis report saved as 'missing_values_report.html'")
#
# ~/.local/lib/python3.10/site-packages/ydata_profiling/profile_report.py in ?(self, output_file, silent)
#     377                 if self.config.html.assets_prefix is None:
#     378                     self.config.html.assets_prefix = str(output_file.stem) + "_assets"
#     379                 create_html_assets(self.config, output_file)
#     380
# --> 381             data = self.to_html()
#     382
#     383             if output_file.suffix != ".html":
#     384                 suffix = output_file.suffix
#
# ~/.local/lib/python3.10/site-packages/ydata_profiling/profile_report.py in ?(self)
#     494         Returns:
#     495             Profiling report html including wrapper.
#     496
#     497         """
# --> 498         return self.html
#
# ~/.local/lib/python3.10/site-packages/ydata_profiling/profile_report.py in ?(self)
#     291     @property
#     292     def html(self) -> str:
#     293         if self._html is None:
# --> 294             self._html = self._render_html()
#     295         return self._html
#
# ~/.local/lib/python3.10/site-packages/ydata_profiling/profile_report.py in ?(self)
#     408     def _render_html(self) -> str:
#     409         from ydata_profiling.report.presentation.flavours import HTMLReport
#     410
# --> 411         report = self.report
#     412
#     413         with tqdm(
#     414             total=1, desc="Render HTML", disable=not self.config.progress_bar
#
# ~/.local/lib/python3.10/site-packages/ydata_profiling/profile_report.py in ?(self)
#     285     @property
#     286     def report(self) -> Root:
#     287         if self._report is None:
# --> 288             self._report = get_report_structure(self.config, self.description_set)
#     289         return self._report
#
# ~/.local/lib/python3.10/site-packages/ydata_profiling/profile_report.py in ?(self)
#     267     @property
#     268     def description_set(self) -> BaseDescription:
#     269         if self._description_set is None:
# --> 270             self._description_set = describe_df(
#     271                 self.config,
#     272                 self.df,
#     273                 self.summarizer,
#
# ~/.local/lib/python3.10/site-packages/ydata_profiling/model/describe.py in ?(config, df, summarizer, typeset, sample)
#      85         date_start = datetime.utcnow()
#      86
#      87         # Variable-specific
#      88         pbar.total += len(df.columns)
# ---> 89         series_description = get_series_descriptions(
#      90             config, df, summarizer, typeset, pbar
#      91         )
#      92
#
# ~/.local/lib/python3.10/site-packages/ydata_profiling/model/summary.py in ?(config, df, summarizer, typeset, pbar)
#      58     typeset: VisionsTypeset,
#      59     pbar: tqdm,
#      60 ) -> dict:
#      61     if isinstance(df, pd.DataFrame):
# ---> 62         return pandas_get_series_descriptions(config, df, summarizer, typeset, pbar)
#      63     elif isinstance(df, sparkDataFrame):  # type: ignore
#      64         return get_series_descriptions_spark(config, df, summarizer, typeset, pbar)
#      65     else:
#
# ~/.local/lib/python3.10/site-packages/ydata_profiling/model/pandas/summary_pandas.py in ?(config, df, summarizer, typeset, pbar)
#      94             for name, series in df.items()
#      95         }
#      96
#      97         for future in tqdm(future_to_col.keys(), total=len(future_to_col)):
# ---> 98             name, description = future.result()
#      99             series_description[name] = description
#     100
#     101     return sort_column_names(series_description, config.sort)
#
# /usr/local/lib/python3.10/concurrent/futures/_base.py in ?(self, timeout)
#     459                 else:
#     460                     raise TimeoutError()
#     461         finally:
#     462             # Break a reference cycle with the exception in self._exception
# --> 463             self = None
#
# /usr/local/lib/python3.10/concurrent/futures/_base.py in ?(self)
#     402             try:
#     403                 raise self._exception
#     404             finally:
#     405                 # Break a reference cycle with the exception in self._exception
# --> 406                 self = None
#     407         else:
#     408             return self._result
#
# /usr/local/lib/python3.10/concurrent/futures/thread.py in ?(self)
#      58             result = self.fn(*self.args, **self.kwargs)
#      59         except BaseException as exc:
#      60             self.future.set_exception(exc)
#      61             # Break a reference cycle with the exception 'exc'
# ---> 62             self = None
#      63         else:
#      64             self.future.set_result(result)
#
# ~/.local/lib/python3.10/site-packages/ydata_profiling/model/pandas/summary_pandas.py in ?(name, series)
#      78     def describe_column(name: str, series: pd.Series) -> Tuple[str, dict]:
#      79         """Process a single series to get the column description."""
#      80         pbar.set_postfix_str(f"Describe variable: {name}")
# ---> 81         description = pandas_describe_1d(config, series, summarizer, typeset)
#      82         pbar.update()
#      83         return name, description
#
# ~/.local/lib/python3.10/site-packages/ydata_profiling/model/pandas/summary_pandas.py in ?(config, series, summarizer, typeset)
#      59         # [new dtypes, changed using `astype` function are now considered]
#      60         vtype = typeset.detect_type(series)
#      61
#      62     typeset.type_schema[series.name] = vtype  # type:ignore
# ---> 63     summary = summarizer.summarize(config, series, dtype=vtype)
#      64     # Cast type is only used on unsupported columns rendering pipeline
#      65     # to indicate the correct variable type when inference is not possible
#      66     summary["cast_type"] = cast_type
#
# ~/.local/lib/python3.10/site-packages/ydata_profiling/model/summarizer.py in ?(self, config, series, dtype)
#      46     def summarize(
#      47         self, config: Settings, series: pd.Series, dtype: Type[VisionsBaseType]
#      48     ) -> dict:
#      49         """Generates the summary for a given series"""
# ---> 50         return self.handle(str(dtype), config, series, {"type": str(dtype)})
#
# ~/.local/lib/python3.10/site-packages/ydata_profiling/model/handler.py in ?(self, dtype, *args, **kwargs)
#      55             object: a tuple containing the config, the dataset series and the summary extracted
#      56         """
#      57         funcs = self.mapping.get(dtype, [])
#      58         op = compose(funcs)
# ---> 59         summary = op(*args)[-1]
#      60         return summary
#
# ~/.local/lib/python3.10/site-packages/ydata_profiling/model/handler.py in ?(*args)
#      18     def composed_function(*args) -> List[Any]:
#      19         result = args  # Start with the input arguments
#      20         for func in functions:
# ---> 21             result = func(*result) if isinstance(result, tuple) else func(result)
#      22         return result  # type: ignore
#
# ~/.local/lib/python3.10/site-packages/ydata_profiling/model/summary_algorithms.py in ?(config, series, summary)
#      68         config: Settings, series: pd.Series, summary: dict
#      69     ) -> Tuple[Settings, pd.Series, dict]:
#      70         if not summary["hashable"]:
#      71             return config, series, summary
# ---> 72         return fn(config, series, summary)
#
# ~/.local/lib/python3.10/site-packages/ydata_profiling/model/summary_algorithms.py in ?(config, series, summary)
#      85     ) -> Tuple[Settings, pd.Series, dict]:
#      86         if series.hasnans:
#      87             series = series.dropna()
#      88
# ---> 89         return fn(config, series, summary)
#
# ~/.local/lib/python3.10/site-packages/ydata_profiling/model/pandas/describe_categorical_pandas.py in ?(config, series, summary)
#     247         summary.update({"first_rows": series.head(5)})
#     248
#     249     chi_squared_threshold = config.vars.num.chi_squared_threshold
#     250     if chi_squared_threshold > 0.0:
# --> 251         summary["chi_squared"] = chi_square(histogram=value_counts.values)
#     252
#     253     if config.vars.cat.length:
#     254         summary.update(length_summary_vc(value_counts))
#
# ~/.local/lib/python3.10/site-packages/ydata_profiling/model/summary_algorithms.py in ?(values, histogram)
#      56         bins = np.histogram_bin_edges(values, bins="auto")
#      57         histogram, _ = np.histogram(values, bins=bins)
#      58     if len(histogram) == 0 or np.sum(histogram) == 0:
#      59         return {"statistic": 0, "pvalue": 0}
# ---> 60     return dict(chisquare(histogram)._asdict())
#
# ~/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py in ?(f_obs, f_exp, ddof, axis, sum_check)
#    7502     (2.0, 0.73575888234288467)
#    7503
#    7504     The calculation of the p-values is done by broadcasting the
#    7505     test statistic with `ddof`.
# -> 7506
#    7507     >>> power_divergence([16, 18, 16, 14, 12, 12], ddof=[0,1,2])
#    7508     (2.0, array([ 0.84914504,  0.73575888,  0.5724067 ]))
#    7509
#
# ~/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py in ?(f_obs, f_exp, ddof, axis, lambda_, sum_check)
#    7352     .. versionadded:: 0.13.0
#    7353
#    7354     References
#    7355     ----------
# -> 7356     .. [1] Lowry, Richard.  "Concepts and Applications of Inferential
#    7357            Statistics". Chapter 8.
#    7358            https://web.archive.org/web/20171015035606/http://faculty.vassar.edu/lowry/ch8pt1.html
#    7359     .. [2] "Chi-squared test", https://en.wikipedia.org/wiki/Chi-squared_test
#
# AttributeError: 'float' object has no attribute 'ndim'

# %% [markdown]
# ### Task 3: Analyze Data Types Using Pandas-Profiling
# **Description**: Use Pandas-Profiling to analyze and check data types of your dataset.

# %%
# Write your code from here
import pandas as pd
from ydata_profiling import ProfileReport

# Sample dataset with different data types
data = {
    "name": ["Alice", "Bob", "Charlie", "David", "Eve"],
    "age": [25, None, 35, 40, None],
    "email": ["alice@example.com", "bob@example.com", "charlie@example.com", "david@example.com", "eve@example.com"],
    "income": [50000, 60000, None, 80000, None],
    "is_active": [True, False, True, True, False]
}

# Create DataFrame
df = pd.DataFrame(data)

# Generate profile report focused on data types and basic info with minimal=True for compatibility
profile = ProfileReport(df, title="Data Types Analysis Report", minimal=True)

# Save the report to an HTML file
profile.to_file("data_types_analysis_report.html")

print("Data types analysis report saved as 'data_types_analysis_report.html'")
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 336.10it/s]0<00:00, 120.62it/s, Describe variable: is_active]
# Summarize dataset: 100%|██████████| 11/11 [00:00<00:00, 286.22it/s, Completed]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 21
#      18 profile = ProfileReport(df, title="Data Types Analysis Report", minimal=True)
#      20 # Save the report to an HTML file
# ---> 21 profile.to_file("data_types_analysis_report.html")
#      23 print("Data types analysis report saved as 'data_types_analysis_report.html'")
#
# File ~/.local/lib/python3.10/site-packages/ydata_profiling/profile_report.py:381, in ProfileReport.to_file(self, output_file, silent)
#     378         self.config.html.assets_prefix = str(output_file.stem) + "_assets"
#     379     create_html_assets(self.config, output_file)
# --> 381 data = self.to_html()
#     383 if output_file.suffix != ".html":
#     384     suffix = output_file.suffix
#
# File ~/.local/lib/python3.10/site-packages/ydata_profiling/profile_report.py:498, in ProfileReport.to_html(self)
#     490 def to_html(self) -> str:
#     491     """Generate and return complete template as lengthy string
#     492         for using with frameworks.
#     493
#    (...)
#     496
#     497     """
# --> 498     return self.html
#
# File ~/.local/lib/python3.10/site-packages/ydata_profiling/profile_report.py:294, in ProfileReport.html(self)
#     291 @property
#     292 def html(self) -> str:
#     293     if self._html is None:
# --> 294         self._html = self._render_html()
#     295     return self._html
#
# File ~/.local/lib/python3.10/site-packages/ydata_profiling/profile_report.py:411, in ProfileReport._render_html(self)
#     408 def _render_html(self) -> str:
#     409     from ydata_profiling.report.presentation.flavours import HTMLReport
# --> 411     report = self.report
#     413     with tqdm(
#     414         total=1, desc="Render HTML", disable=not self.config.progress_bar
#     415     ) as pbar:
#     416         html = HTMLReport(copy.deepcopy(report)).render(
#     417             nav=self.config.html.navbar_show,
#     418             offline=self.config.html.use_local_assets,
#    (...)
#     426             version=self.description_set.package["ydata_profiling_version"],
#     427         )
#
# File ~/.local/lib/python3.10/site-packages/ydata_profiling/profile_report.py:288, in ProfileReport.report(self)
#     285 @property
#     286 def report(self) -> Root:
#     287     if self._report is None:
# --> 288         self._report = get_report_structure(self.config, self.description_set)
#     289     return self._report
#
# File ~/.local/lib/python3.10/site-packages/ydata_profiling/report/structure/report.py:388, in get_report_structure(config, summary)
#     368 section_items: List[Renderable] = [
#     369     Container(
#     370         get_dataset_items(config, summary, alerts),
#    (...)
#     375     ),
#     376 ]
#     378 if len(summary.variables) > 0:
#     379     section_items.append(
#     380         Dropdown(
#     381             name="Variables",
#     382             anchor_id="variables-dropdown",
#     383             id="variables-dropdown",
#     384             is_row=False,
#     385             classes=["form-select"],
#     386             items=list(summary.variables),
#     387             item=Container(
# --> 388                 render_variables_section(config, summary),
#     389                 sequence_type="accordion",
#     390                 name="Variables",
#     391                 anchor_id="variables",
#     392             ),
#     393         )
#     394     )
#     396 scatter_items = get_interactions(config, summary.scatter)
#     397 if len(scatter_items) > 0:
#
# File ~/.local/lib/python3.10/site-packages/ydata_profiling/report/structure/report.py:162, in render_variables_section(config, dataframe_summary)
#     160     variable_type = summary["type"]
#     161 render_map_type = render_map.get(variable_type, render_map["Unsupported"])
# --> 162 template_variables.update(render_map_type(config, template_variables))
#     164 # Ignore these
#     165 if reject_variables:
#
# File ~/.local/lib/python3.10/site-packages/ydata_profiling/report/structure/variables/render_text.py:81, in render_text(config, summary)
#      77 top_items.append(table)
#      79 if words and "word_counts" in summary:
#      80     mini_wordcloud = Image(
# ---> 81         plot_word_cloud(config, summary["word_counts"]),
#      82         image_format=config.plot.image_format,
#      83         alt="Mini wordcloud",
#      84     )
#      85     top_items.append(mini_wordcloud)
#      86 template_variables["top"] = Container(top_items, sequence_type="grid")
#
# File /usr/local/lib/python3.10/contextlib.py:78, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
# ---> 78     with self._recreate_cm():
#      79         return func(*args, **kwds)
#
# File /usr/local/lib/python3.10/contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File ~/.local/lib/python3.10/site-packages/ydata_profiling/visualisation/context.py:82, in manage_matplotlib_context()
#      80     yield
#      81 finally:
# ---> 82     deregister_matplotlib_converters()  # revert to original unit registries
#      83     with warnings.catch_warnings():
#      84         warnings.filterwarnings(
#      85             "ignore", category=matplotlib.MatplotlibDeprecationWarning
#      86         )
#
# File ~/.local/lib/python3.10/site-packages/pandas/plotting/_misc.py:151, in deregister()
#     112 def deregister() -> None:
#     113     """
#     114     Remove pandas formatters and converters.
#     115
#    (...)
#     149     TypeError: float() argument must be a string or a real number, not 'Period'
#     150     """
# --> 151     plot_backend = _get_plot_backend("matplotlib")
#     152     plot_backend.deregister()
#
# File ~/.local/lib/python3.10/site-packages/pandas/plotting/_core.py:1947, in _get_plot_backend(backend)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/.local/lib/python3.10/site-packages/pandas/plotting/_core.py:1877, in _load_backend(backend)
#    1872         module = importlib.import_module("pandas.plotting._matplotlib")
#    1873     except ImportError:
#    1874         raise ImportError(
#    1875             "matplotlib is required for plotting when the "
#    1876             'default backend "matplotlib" is selected.'
# -> 1877         ) from None
#    1878     return module
#    1880 found_backend = False
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.

# %% [markdown]
# ### Task 4: Detect Unique Values and Duplicates
# **Description**: Use Pandas-Profiling to detect unique values and duplicates in your dataset.

# %%
# Write your code from here
