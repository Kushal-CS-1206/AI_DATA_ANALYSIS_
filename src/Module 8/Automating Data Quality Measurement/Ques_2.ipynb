# %% [markdown]
# ### Task 1: Validate Data with a Custom Expectation in Great Expectations
# **Description**: Create a custom expectation and validate data with Great Expectations.
#
# **Load a sample DataFrame**
#
# data = {
# 'age': [25, 30, 35, 40, 45],
# 'income': [50000, 60000, 75000, None, 100000]
# }

# %%
# !pip install great_expectations
import pandas as pd
from great_expectations.data_context import DataContext
from great_expectations.core.batch import BatchRequest

# Sample DataFrame
df = pd.DataFrame({
    "age": [25, 30, 35, 40, 45],
    "income": [50000, 60000, 75000, None, 100000]
})

# Create a minimal in-memory DataContext config
context_config = {
    "datasources": {
        "my_pandas_datasource": {
            "class_name": "Datasource",
            "execution_engine": {
                "class_name": "PandasExecutionEngine"
            },
            "data_connectors": {
                "default_runtime_data_connector": {
                    "class_name": "RuntimeDataConnector",
                    "batch_identifiers": ["default_identifier_name"]
                }
            }
        }
    },
    "stores": {
        "expectations_store": {
            "class_name": "InMemoryStore"
        },
        "validations_store": {
            "class_name": "InMemoryStore"
        },
        "evaluation_parameter_store": {
            "class_name": "InMemoryStore"
        }
    },
    "expectations_store_name": "expectations_store",
    "validations_store_name": "validations_store",
    "evaluation_parameter_store_name": "evaluation_parameter_store",
    "data_docs_sites": {},
    "anonymous_usage_statistics": {
        "enabled": False
    }
}

# Initialize DataContext with the config
context = DataContext(project_config=context_config)

# Create a BatchRequest with your DataFrame
batch_request = BatchRequest(
    datasource_name="my_pandas_datasource",
    data_connector_name="default_runtime_data_connector",
    data_asset_name="my_data_asset",
    runtime_parameters={"batch_data": df},
    batch_identifiers={"default_identifier_name": "default_id"},
)

# Get a Validator
validator = context.get_validator(batch_request=batch_request)

# Add expectation: income values >= 50000 (None values allowed)
result = validator.expect_column_values_to_be_between(
    column="income",
    min_value=50000,
    mostly=1.0,
)

print(result)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: great_expectations in /home/vscode/.local/lib/python3.10/site-packages (0.16.15)
# Requirement already satisfied: jsonpatch>=1.22 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (1.33)
# Requirement already satisfied: colorama>=0.4.3 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (0.4.6)
# Requirement already satisfied: pyparsing>=2.4 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (2.8.2)
# Requirement already satisfied: cryptography>=3.2 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (41.0.4)
# Requirement already satisfied: makefun<2,>=1.7.0 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (1.16.0)
# Requirement already satisfied: notebook>=6.4.10 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (7.4.2)
# Requirement already satisfied: ipywidgets>=7.5.1 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (8.1.7)
# Requirement already satisfied: pytz>=2021.3 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (2023.3.post1)
# Requirement already satisfied: importlib-metadata>=1.7.0 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (6.8.0)
# Requirement already satisfied: pydantic<2.0,>=1.9.2 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (1.10.22)
# Requirement already satisfied: numpy>=1.23.0 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (1.26.4)
# Requirement already satisfied: nbformat>=5.0 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (5.10.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.7.1 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (3.20.1)
# Requirement already satisfied: mistune>=0.8.4 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (3.1.3)
# Requirement already satisfied: jsonschema>=2.5.1 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (4.19.1)
# Requirement already satisfied: ruamel.yaml<0.17.18,>=0.16 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (0.17.17)
# Requirement already satisfied: tzlocal>=1.2 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (5.3.1)
# Requirement already satisfied: packaging in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (23.2)
# Requirement already satisfied: urllib3>=1.26 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (1.26.17)
# Requirement already satisfied: pandas<2.0.0,>=1.3.0 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (1.5.3)
# Requirement already satisfied: altair<5.0.0,>=4.2.1 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (4.2.2)
# Requirement already satisfied: Ipython>=7.16.3 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (8.36.0)
# Requirement already satisfied: jinja2>=2.10 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (3.1.2)
# Requirement already satisfied: tqdm>=4.59.0 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (4.67.1)
# Requirement already satisfied: scipy>=1.6.0 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (1.10.1)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (4.8.0)
# Requirement already satisfied: Click>=7.1.2 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (8.1.7)
# Requirement already satisfied: requests>=2.20 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (2.31.0)
# Requirement already satisfied: toolz in /home/vscode/.local/lib/python3.10/site-packages (from altair<5.0.0,>=4.2.1->great_expectations) (1.0.0)
# Requirement already satisfied: entrypoints in /home/vscode/.local/lib/python3.10/site-packages (from altair<5.0.0,>=4.2.1->great_expectations) (0.4)
# Requirement already satisfied: cffi>=1.12 in /home/vscode/.local/lib/python3.10/site-packages (from cryptography>=3.2->great_expectations) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in /home/vscode/.local/lib/python3.10/site-packages (from importlib-metadata>=1.7.0->great_expectations) (3.17.0)
# Requirement already satisfied: stack_data in /home/vscode/.local/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /home/vscode/.local/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations) (5.14.3)
# Requirement already satisfied: decorator in /home/vscode/.local/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /home/vscode/.local/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations) (0.19.2)
# Requirement already satisfied: pygments>=2.4.0 in /home/vscode/.local/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations) (2.16.1)
# Requirement already satisfied: matplotlib-inline in /home/vscode/.local/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/vscode/.local/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations) (3.0.51)
# Requirement already satisfied: exceptiongroup in /home/vscode/.local/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations) (1.1.3)
# Requirement already satisfied: pexpect>4.3 in /home/vscode/.local/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations) (4.9.0)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/vscode/.local/lib/python3.10/site-packages (from ipywidgets>=7.5.1->great_expectations) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/vscode/.local/lib/python3.10/site-packages (from ipywidgets>=7.5.1->great_expectations) (3.0.15)
# Requirement already satisfied: comm>=0.1.3 in /home/vscode/.local/lib/python3.10/site-packages (from ipywidgets>=7.5.1->great_expectations) (0.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/vscode/.local/lib/python3.10/site-packages (from jinja2>=2.10->great_expectations) (2.1.3)
# Requirement already satisfied: jsonpointer>=1.9 in /home/vscode/.local/lib/python3.10/site-packages (from jsonpatch>=1.22->great_expectations) (3.0.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/vscode/.local/lib/python3.10/site-packages (from jsonschema>=2.5.1->great_expectations) (2023.7.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/vscode/.local/lib/python3.10/site-packages (from jsonschema>=2.5.1->great_expectations) (0.10.4)
# Requirement already satisfied: attrs>=22.2.0 in /home/vscode/.local/lib/python3.10/site-packages (from jsonschema>=2.5.1->great_expectations) (23.1.0)
# Requirement already satisfied: referencing>=0.28.4 in /home/vscode/.local/lib/python3.10/site-packages (from jsonschema>=2.5.1->great_expectations) (0.30.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/vscode/.local/lib/python3.10/site-packages (from nbformat>=5.0->great_expectations) (5.7.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/vscode/.local/lib/python3.10/site-packages (from nbformat>=5.0->great_expectations) (2.21.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/vscode/.local/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations) (2.16.0)
# Requirement already satisfied: jupyterlab<4.5,>=4.4.0 in /home/vscode/.local/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations) (4.4.2)
# Requirement already satisfied: tornado>=6.2.0 in /home/vscode/.local/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations) (6.4.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /home/vscode/.local/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations) (2.27.3)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /home/vscode/.local/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations) (0.2.4)
# Requirement already satisfied: six>=1.5 in /home/vscode/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.1->great_expectations) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/vscode/.local/lib/python3.10/site-packages (from requests>=2.20->great_expectations) (3.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vscode/.local/lib/python3.10/site-packages (from requests>=2.20->great_expectations) (2023.7.22)
# Requirement already satisfied: idna<4,>=2.5 in /home/vscode/.local/lib/python3.10/site-packages (from requests>=2.20->great_expectations) (3.4)
# Requirement already satisfied: pycparser in /home/vscode/.local/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=3.2->great_expectations) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/vscode/.local/lib/python3.10/site-packages (from jedi>=0.16->Ipython>=7.16.3->great_expectations) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=5.0->great_expectations) (4.3.8)
# Requirement already satisfied: jupyter-events>=0.11.0 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (0.12.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (8.6.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (7.16.6)
# Requirement already satisfied: send2trash>=1.8.2 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (1.8.3)
# Requirement already satisfied: overrides>=5.0 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (0.22.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (0.18.1)
# Requirement already satisfied: anyio>=3.1.0 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (4.0.0)
# Requirement already satisfied: websocket-client>=1.7 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (1.8.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (23.1.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (0.5.3)
# Requirement already satisfied: pyzmq>=24 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (26.4.0)
# Requirement already satisfied: setuptools>=41.1.0 in /usr/local/lib/python3.10/site-packages (from jupyterlab<4.5,>=4.4.0->notebook>=6.4.10->great_expectations) (67.8.0)
# Requirement already satisfied: httpx>=0.25.0 in /home/vscode/.local/lib/python3.10/site-packages (from jupyterlab<4.5,>=4.4.0->notebook>=6.4.10->great_expectations) (0.28.1)
# Requirement already satisfied: async-lru>=1.0.0 in /home/vscode/.local/lib/python3.10/site-packages (from jupyterlab<4.5,>=4.4.0->notebook>=6.4.10->great_expectations) (2.0.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/vscode/.local/lib/python3.10/site-packages (from jupyterlab<4.5,>=4.4.0->notebook>=6.4.10->great_expectations) (2.2.5)
# Requirement already satisfied: ipykernel>=6.5.0 in /home/vscode/.local/lib/python3.10/site-packages (from jupyterlab<4.5,>=4.4.0->notebook>=6.4.10->great_expectations) (6.29.5)
# Requirement already satisfied: tomli>=1.2.2 in /home/vscode/.local/lib/python3.10/site-packages (from jupyterlab<4.5,>=4.4.0->notebook>=6.4.10->great_expectations) (2.2.1)
# Requirement already satisfied: babel>=2.10 in /home/vscode/.local/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.4.10->great_expectations) (2.13.0)
# Requirement already satisfied: json5>=0.9.0 in /home/vscode/.local/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.4.10->great_expectations) (0.12.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/vscode/.local/lib/python3.10/site-packages (from pexpect>4.3->Ipython>=7.16.3->great_expectations) (0.7.0)
# Requirement already satisfied: wcwidth in /home/vscode/.local/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->Ipython>=7.16.3->great_expectations) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/vscode/.local/lib/python3.10/site-packages (from stack_data->Ipython>=7.16.3->great_expectations) (2.2.0)
# Requirement already satisfied: pure-eval in /home/vscode/.local/lib/python3.10/site-packages (from stack_data->Ipython>=7.16.3->great_expectations) (0.2.3)
# Requirement already satisfied: asttokens>=2.1.0 in /home/vscode/.local/lib/python3.10/site-packages (from stack_data->Ipython>=7.16.3->great_expectations) (3.0.0)
# Requirement already satisfied: sniffio>=1.1 in /home/vscode/.local/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/vscode/.local/lib/python3.10/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (21.2.0)
# Requirement already satisfied: httpcore==1.* in /home/vscode/.local/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab<4.5,>=4.4.0->notebook>=6.4.10->great_expectations) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/vscode/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.5,>=4.4.0->notebook>=6.4.10->great_expectations) (0.16.0)
# Requirement already satisfied: psutil in /home/vscode/.local/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.0->notebook>=6.4.10->great_expectations) (5.9.5)
# Requirement already satisfied: debugpy>=1.6.5 in /home/vscode/.local/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.0->notebook>=6.4.10->great_expectations) (1.8.14)
# Requirement already satisfied: nest-asyncio in /home/vscode/.local/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.0->notebook>=6.4.10->great_expectations) (1.6.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (3.3.0)
# Requirement already satisfied: rfc3339-validator in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (0.1.1)
# Requirement already satisfied: pyyaml>=5.3 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (6.0.1)
# Requirement already satisfied: defusedxml in /home/vscode/.local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in /home/vscode/.local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (4.13.4)
# Requirement already satisfied: jupyterlab-pygments in /home/vscode/.local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (0.3.0)
# Requirement already satisfied: nbclient>=0.5.0 in /home/vscode/.local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (0.10.2)
# Requirement already satisfied: bleach[css]!=5.0.0 in /home/vscode/.local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (6.2.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/vscode/.local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (1.5.1)
# Requirement already satisfied: webencodings in /home/vscode/.local/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /home/vscode/.local/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (1.4.0)
# Requirement already satisfied: fqdn in /home/vscode/.local/lib/python3.10/site-packages (from jsonschema>=2.5.1->great_expectations) (1.5.1)
# Requirement already satisfied: uri-template in /home/vscode/.local/lib/python3.10/site-packages (from jsonschema>=2.5.1->great_expectations) (1.3.0)
# Requirement already satisfied: isoduration in /home/vscode/.local/lib/python3.10/site-packages (from jsonschema>=2.5.1->great_expectations) (20.11.0)
# Requirement already satisfied: webcolors>=1.11 in /home/vscode/.local/lib/python3.10/site-packages (from jsonschema>=2.5.1->great_expectations) (24.11.1)
# Requirement already satisfied: soupsieve>1.2 in /home/vscode/.local/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great_expectations) (2.7)
# Requirement already satisfied: arrow>=0.15.0 in /home/vscode/.local/lib/python3.10/site-packages (from isoduration->jsonschema>=2.5.1->great_expectations) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /home/vscode/.local/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema>=2.5.1->great_expectations) (2.9.0.20250516)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 49
#      13 context_config = {
#      14     "datasources": {
#      15         "my_pandas_datasource": {
#    (...)
#      45     }
#      46 }
#      48 # Initialize DataContext with the config
# ---> 49 context = DataContext(project_config=context_config)
#      51 # Create a BatchRequest with your DataFrame
#      52 batch_request = BatchRequest(
#      53     datasource_name="my_pandas_datasource",
#      54     data_connector_name="default_runtime_data_connector",
#    (...)
#      57     batch_identifiers={"default_identifier_name": "default_id"},
#      58 )
#
# TypeError: DataContext() got an unexpected keyword argument 'project_config'

# %% [markdown]
# ### Task 2: Implement a Basic Alert System for Data Quality Drops
# **Description**: Set up a basic alert system that triggers when data quality drops.

# %%
import pandas as pd

def check_data_quality(df, completeness_threshold=0.9):
    completeness = df.notnull().mean().mean()
    if completeness < completeness_threshold:
        print(f"ALERT: Data quality dropped! Completeness: {completeness:.2f}")
    else:
        print(f"Data quality is good. Completeness: {completeness:.2f}")

data_good = {
    "A": [1, 2, 3, None],
    "B": [4, 5, None, 7]
}
df_good = pd.DataFrame(data_good)

data_bad = {
    "A": [None, None, None, None],
    "B": [None, None, None, None]
}
df_bad = pd.DataFrame(data_bad)

check_data_quality(df_good)
check_data_quality(df_bad)
# Out:
# ALERT: Data quality dropped! Completeness: 0.75
# ALERT: Data quality dropped! Completeness: 0.00

# %% [markdown]
# ### Task 3: Real-time Data Quality Monitoring with Python and Great Expectations
# **Description**: Implement a system that monitors data quality in real-time.

# %%
import great_expectations as ge
import pandas as pd
import time

data_samples = [
    {"id": 1, "value": 10},
    {"id": 2, "value": None},
    {"id": 3, "value": 15},
    {"id": 4, "value": 20},
]

context = ge.get_context()

suite_name = "realtime_data_quality_suite"
try:
    suite = context.get_expectation_suite(suite_name)
except Exception:
    suite = context.create_expectation_suite(suite_name, overwrite_existing=True)

def create_or_update_expectations(df):
    batch = ge.from_pandas(df)
    batch.expect_column_values_to_not_be_null("value")
    return batch

def monitor_data_stream():
    for sample in data_samples:
        df = pd.DataFrame([sample])
        batch = create_or_update_expectations(df)
        results = batch.validate(expectation_suite=suite)
        print(f"Data sample id {sample['id']} validation results: {results['success']}")
        time.sleep(1)

monitor_data_stream()
# Out:
# Data sample id 1 validation results: True
# Data sample id 2 validation results: True
# Data sample id 3 validation results: True
# Data sample id 4 validation results: True
